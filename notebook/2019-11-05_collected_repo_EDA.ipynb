# %%
import sys
sys.path.append("../")

# %%
from src.download_commit_data import Config
from tqdm import tqdm_notebook

import os
import github
import typing
import jsonlines

import pandas as pd
import numpy as np

# %%
with jsonlines.open("../data/repositories/top1000_page1.jsonl") as reader:
    top1000_page1 = [obj for obj in reader.read()]

# %%
with jsonlines.open("../data/repositories/top1000_page2.jsonl") as reader:
    top1000_page2 = [obj for obj in reader.read()]

# %%
df1 = pd.DataFrame(top1000_page1)

# %%
df2 = pd.DataFrame(top1000_page2)

# %%
df = pd.concat([df1, df2])
df = df.drop_duplicates()

# %%
df[:10]
# Out:
#                           full_name language  commits  stargazers_count  \
# 0  donnemartin/system-design-primer   Python      275             75863
# 1              vinta/awesome-python   Python     1399             75128
# 2           public-apis/public-apis   Python     2129             64406
# 3                 tensorflow/models   Python     3936             58983
# 4               ytdl-org/youtube-dl   Python    17388             57370
# 5                      nvbn/thefuck   Python     1547             50122
# 6                     pallets/flask   Python     3776             47344
# 7                  keras-team/keras   Python     5341             45176
# 8                     django/django   Python    27513             45043
# 9              jakubroztocil/httpie   Python     1112             43661
#
#    watchers_count  forks_count    size  archived   fork
# 0           75863        12336    4330     False  False
# 1           75128        14768    5316     False  False
# 2           64406         7197    2715     False  False
# 3           58983        37248  523487     False  False
# 4           57370         9954   57035     False  False
# 5           50122         2506    2788     False  False
# 6           47344        13032    7321     False  False
# 7           45176        17170   13322     False  False
# 8           45043        19418  190821     False  False
# 9           43661         2866    5563     False  False

# %%
def basic_stats(field, title):
    mean = field.mean()
    _min, _max = field.min(), field.max()
    percentile_0_25 = field.quantile(0.25)
    percentile_0_50 = field.quantile(0.50)
    percentile_0_95 = field.quantile(0.95)
    print(f"""Basic stats for {title}:
    mean={mean:0.2f}
    min={_min:0.2f}
    max={_max:0.2f}
    25_percentile={percentile_0_25:0.2f}
    50_percentile={percentile_0_50:0.2f}
    95_percentile={percentile_0_95:0.2f}
    """)

# %%
basic_stats(df.stargazers_count, "stargazers_count")
# Out:
# Basic stats for stargazers_count:
#     mean=3962.99
#     min=1132.00
#     max=75863.00
#     25_percentile=1488.00
#     50_percentile=2216.00
#     95_percentile=11777.80

# %%
basic_stats(df.commits, "commits")
# Out:
# Basic stats for commits:
#     mean=1902.02
#     min=1.00
#     max=169340.00
#     25_percentile=119.00
#     50_percentile=421.00
#     95_percentile=8320.20

# %%
basic_stats(df.forks_count, "forks_count")
# Out:
# Basic stats for forks_count:
#     mean=870.44
#     min=28.00
#     max=37248.00
#     25_percentile=259.00
#     50_percentile=453.00
#     95_percentile=2663.60

# %%
basic_stats(df["size"], "size")
# Out:
# Basic stats for size:
#     mean=35081.73
#     min=7.00
#     max=2741739.00
#     25_percentile=935.00
#     50_percentile=4313.00
#     95_percentile=150054.20

# %%
df[df.fork == True]
# Out:
# Empty DataFrame
# Columns: [full_name, language, commits, stargazers_count, watchers_count, forks_count, size, archived, fork]
# Index: []

# %%
df[df.archived == True]
# Out:
#                                              full_name language  commits  \
# 60                               reddit-archive/reddit   Python     7956
# 171  eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee/eeeeeeeeeeeee...   Python      415
# 186                                    openai/universe   Python      210
# 233                                        p-e-w/maybe   Python       78
# 330                               xchaoinfo/fuck-login   Python      117
# 353                                    yahoo/open_nsfw   Python       13
# 440          facebookarchive/augmented-traffic-control   Python      237
# 654                 not-kennethreitz/osx-gcc-installer   Python       54
# 704                                  byt3bl33d3r/MITMf   Python      467
# 710                                 nryoung/algorithms   Python      279
# 715                             docker/docker-registry   Python     1205
# 828                               gongjianhui/AppleDNS   Python      186
# 857             revolunet/sublimetext-markdown-preview   Python      556
# 858                            openpaperwork/paperwork   Python     3266
# 887                                   RasaHQ/rasa_core   Python     4698
# 892                          ansible/ansible-container   Python     1078
# 946                                   nickoala/telepot   Python      431
# 951                             not-kennethreitz/envoy   Python       85
# 33                                   wrobstory/vincent   Python      424
# 153                                    aploium/zmirror   Python      478
# 309                                  Yelp/osxcollector   Python      342
# 337                               wzpan/dingdang-robot   Python      242
# 375                                    nccgroup/Scout2   Python     1182
# 390                                  twilio/stashboard   Python      304
# 464                               ry/tensorflow-resnet   Python       60
# 583                             lepture/flask-oauthlib   Python      573
# 612                                     dz0ny/leapcast   Python      171
# 634                                    gak/pycallgraph   Python      286
# 713                                   raelgc/scudcloud   Python      954
# 817                                 IronLanguages/main   Python     2216
# 858                       ansible/ansible-modules-core   Python     9857
# 891                                  Thriftpy/thriftpy   Python      650
# 892                                    dagwieers/dstat   Python      514
# 941                      dingdang-robot/dingdang-robot   Python      281
# 990                              gratipay/gratipay.com   Python    11709
#
#      stargazers_count  watchers_count  forks_count     size  archived   fork
# 60              15148           15148         2783    40093      True  False
# 171              7485            7485          672     1236      True  False
# 186              7136            7136          856     1616      True  False
# 233              6471            6471          174      140      True  False
# 330              5356            5356         2005      316      True  False
# 353              5099            5099          971    21634      True  False
# 440              4167            4167          580    12087      True  False
# 654              3089            3089          217      494      True  False
# 704              2878            2878          899     1375      True  False
# 710              2865            2865          721     1866      True  False
# 715              2846            2846          910     6052      True  False
# 828              2443            2443          335      194      True  False
# 857              2377            2377          354     4249      True  False
# 858              2375            2375          161    19075      True  False
# 887              2291            2291         1048  1059972      True  False
# 892              2284            2284          424     4348      True  False
# 946              2249            2249          394     2186      True  False
# 951              2238            2238          273      108      True  False
# 33               2063            2063          241     7081      True  False
# 153              1850            1850          618     1838      True  False
# 309              1686            1686          219      788      True  False
# 337              1648            1648          512     1640      True  False
# 375              1594            1594          284     3191      True  False
# 390              1580            1580          300     4286      True  False
# 464              1475            1475          595     1423      True  False
# 583              1385            1385          423      849      True  False
# 612              1374            1374          186      370      True  False
# 634              1360            1360          223     3045      True  False
# 713              1261            1261          105     3011      True  False
# 817              1199            1199          366   225398      True  False
# 858              1166            1166         2008    14580      True  False
# 891              1149            1149          306      806      True  False
# 892              1149            1149          269      909      True  False
# 941              1160            1160          353     1638      True  False
# 990              1134            1134          345   107722      True  False

# %%
df.sort_values("commits", ascending=True)[:50]
# Out:
#                                            full_name language  commits  \
# 16                           shadowsocks/shadowsocks   Python        1
# 128                              ziggear/shadowsocks   Python        2
# 774                     joshua-wu/deepfakes_faceswap   Python        4
# 859              openai/evolution-strategies-starter   Python        4
# 577                 llSourcell/YOLO_Object_Detection   Python        4
# 495                              angusshire/greenhat   Python        4
# 728                       llSourcell/learn_math_fast   Python        5
# 259                           princeton-vl/CornerNet   Python        5
# 818                   wepe/O2O-Coupon-Usage-Forecast   Python        5
# 545                   openai/finetune-transformer-lm   Python        6
# 983                      ownthink/KnowledgeGraphData   Python        6
# 379              microsoft/c9-python-getting-started   Python        6
# 469                                 mingyuliutw/UNIT   Python        7
# 553                                  moxie0/sslstrip   Python        7
# 251                          viewfinderco/viewfinder   Python        7
# 778                           Newmu/Theano-Tutorials   Python        8
# 857   devnag/pytorch-generative-adversarial-networks   Python        8
# 991                              NVlabs/ffhq-dataset   Python        9
# 494              facebookresearch/video-nonlocal-net   Python        9
# 735                         candlewill/Dialog_Corpus   Python        9
# 848                  codemayq/chinese_chatbot_corpus   Python        9
# 800                           dabeaz/python-cookbook   Python        9
# 819                    rougier/matplotlib-cheatsheet   Python        9
# 460                            ashnkumar/sketch-code   Python       10
# 752                  ChenglongChen/tensorflow-DeepFM   Python       10
# 873                                     deepmind/dnc   Python       10
# 697                                 lijiejie/GitHack   Python       10
# 550                                 nuno-faria/tiler   Python       10
# 544                           sublimehq/anim_encoder   Python       10
# 339                  aaron-xichen/pytorch-playground   Python       10
# 151                                  NVlabs/stylegan   Python       11
# 876                             matthewearl/faceswap   Python       11
# 492                         fendouai/Awesome-Chatbot   Python       11
# 40                                  munificent/vigil   Python       12
# 989                                foolwood/SiamMask   Python       12
# 548                  zllrunning/video-object-removal   Python       12
# 786                                  listen1/listen1   Python       12
# 625                 mshang/python-elevator-challenge   Python       12
# 852                                hackappcom/ibrute   Python       12
# 353                                  yahoo/open_nsfw   Python       13
# 318                                YCG09/chinese_ocr   Python       13
# 642                              seemoo-lab/opendrop   Python       13
# 685  openai/generating-reviews-discovering-sentiment   Python       13
# 569                  hzy46/Deep-Learning-21-Examples   Python       14
# 363                                chiphuyen/lazynlp   Python       14
# 241                            pwxcoo/chinese-xinhua   Python       15
# 796             facebookresearch/poincare-embeddings   Python       15
# 421                             hanzhanggit/StackGAN   Python       15
# 148            kon9chunkit/GitHub-Chinese-Top-Charts   Python       15
# 760                                    noamraph/tqdm   Python       15
#
#      stargazers_count  watchers_count  forks_count    size  archived   fork
# 16              31774           31774        19454     891     False  False
# 128              1880            1880         2511     273     False  False
# 774              2704            2704          960       9     False  False
# 859              1165            1165          226      44     False  False
# 577              1390            1390          682    2264     False  False
# 495              1431            1431          175    1127     False  False
# 728              2822            2822          550      44     False  False
# 259              1770            1770          378      39     False  False
# 818              1199            1199          785    1338     False  False
# 545              1419            1419          368  423329     False  False
# 983              2135            2135          328     826     False  False
# 379              4950            4950         1217    3181     False  False
# 469              1467            1467          282  207206     False  False
# 553              1411            1411          325     519     False  False
# 251              1776            1776          549  117910     False  False
# 778              1216            1216          453     249     False  False
# 857              1166            1166          380       9     False  False
# 991              1134            1134          160    3957     False  False
# 494              1431            1431          274    4527     False  False
# 735              1246            1246          408  101533     False  False
# 848              1175            1175          305     133     False  False
# 800              2495            2495         1275    2062     False  False
# 819              1198            1198          136    4346     False  False
# 460              4025            4025          511    2063     False  False
# 752              1230            1230          559     149     False  False
# 873              2324            2324          429      70     False  False
# 697              1315            1315          558      11     False  False
# 550              3690            3690          170   13666     False  False
# 544              1421            1421          156    1135     False  False
# 339              1647            1647          424      36     False  False
# 151              8118            8118         1645    1716     False  False
# 876              1156            1156          433      11     False  False
# 492              1432            1432          327      13     False  False
# 40               2048            2048           55       8     False  False
# 989              2128            2128          526    7080     False  False
# 548              1415            1415          188  110463     False  False
# 786              2646            2646          232     763     False  False
# 625              1366            1366          194      26     False  False
# 852              1170            1170          453     175     False  False
# 353              5099            5099          971   21634      True  False
# 318              1676            1676          754   92115     False  False
# 642              3133            3133           87      84     False  False
# 685              1321            1321          331  313067     False  False
# 569              3611            3611         1588  141867     False  False
# 363              1617            1617          229      38     False  False
# 241              6372            6372         1388   36271     False  False
# 796              1206            1206          156     379     False  False
# 421              1504            1504          378    1929     False  False
# 148              8178            8178          993    2166     False  False
# 760              2743            2743          103       7     False  False

# %%
df.sort_values("commits", ascending=True)[:50]
# Out:
#                                            full_name language  commits  \
# 16                           shadowsocks/shadowsocks   Python        1
# 128                              ziggear/shadowsocks   Python        2
# 774                     joshua-wu/deepfakes_faceswap   Python        4
# 859              openai/evolution-strategies-starter   Python        4
# 577                 llSourcell/YOLO_Object_Detection   Python        4
# 495                              angusshire/greenhat   Python        4
# 728                       llSourcell/learn_math_fast   Python        5
# 259                           princeton-vl/CornerNet   Python        5
# 818                   wepe/O2O-Coupon-Usage-Forecast   Python        5
# 545                   openai/finetune-transformer-lm   Python        6
# 983                      ownthink/KnowledgeGraphData   Python        6
# 379              microsoft/c9-python-getting-started   Python        6
# 469                                 mingyuliutw/UNIT   Python        7
# 553                                  moxie0/sslstrip   Python        7
# 251                          viewfinderco/viewfinder   Python        7
# 778                           Newmu/Theano-Tutorials   Python        8
# 857   devnag/pytorch-generative-adversarial-networks   Python        8
# 991                              NVlabs/ffhq-dataset   Python        9
# 494              facebookresearch/video-nonlocal-net   Python        9
# 735                         candlewill/Dialog_Corpus   Python        9
# 848                  codemayq/chinese_chatbot_corpus   Python        9
# 800                           dabeaz/python-cookbook   Python        9
# 819                    rougier/matplotlib-cheatsheet   Python        9
# 460                            ashnkumar/sketch-code   Python       10
# 752                  ChenglongChen/tensorflow-DeepFM   Python       10
# 873                                     deepmind/dnc   Python       10
# 697                                 lijiejie/GitHack   Python       10
# 550                                 nuno-faria/tiler   Python       10
# 544                           sublimehq/anim_encoder   Python       10
# 339                  aaron-xichen/pytorch-playground   Python       10
# 151                                  NVlabs/stylegan   Python       11
# 876                             matthewearl/faceswap   Python       11
# 492                         fendouai/Awesome-Chatbot   Python       11
# 40                                  munificent/vigil   Python       12
# 989                                foolwood/SiamMask   Python       12
# 548                  zllrunning/video-object-removal   Python       12
# 786                                  listen1/listen1   Python       12
# 625                 mshang/python-elevator-challenge   Python       12
# 852                                hackappcom/ibrute   Python       12
# 353                                  yahoo/open_nsfw   Python       13
# 318                                YCG09/chinese_ocr   Python       13
# 642                              seemoo-lab/opendrop   Python       13
# 685  openai/generating-reviews-discovering-sentiment   Python       13
# 569                  hzy46/Deep-Learning-21-Examples   Python       14
# 363                                chiphuyen/lazynlp   Python       14
# 241                            pwxcoo/chinese-xinhua   Python       15
# 796             facebookresearch/poincare-embeddings   Python       15
# 421                             hanzhanggit/StackGAN   Python       15
# 148            kon9chunkit/GitHub-Chinese-Top-Charts   Python       15
# 760                                    noamraph/tqdm   Python       15
#
#      stargazers_count  watchers_count  forks_count    size  archived   fork
# 16              31774           31774        19454     891     False  False
# 128              1880            1880         2511     273     False  False
# 774              2704            2704          960       9     False  False
# 859              1165            1165          226      44     False  False
# 577              1390            1390          682    2264     False  False
# 495              1431            1431          175    1127     False  False
# 728              2822            2822          550      44     False  False
# 259              1770            1770          378      39     False  False
# 818              1199            1199          785    1338     False  False
# 545              1419            1419          368  423329     False  False
# 983              2135            2135          328     826     False  False
# 379              4950            4950         1217    3181     False  False
# 469              1467            1467          282  207206     False  False
# 553              1411            1411          325     519     False  False
# 251              1776            1776          549  117910     False  False
# 778              1216            1216          453     249     False  False
# 857              1166            1166          380       9     False  False
# 991              1134            1134          160    3957     False  False
# 494              1431            1431          274    4527     False  False
# 735              1246            1246          408  101533     False  False
# 848              1175            1175          305     133     False  False
# 800              2495            2495         1275    2062     False  False
# 819              1198            1198          136    4346     False  False
# 460              4025            4025          511    2063     False  False
# 752              1230            1230          559     149     False  False
# 873              2324            2324          429      70     False  False
# 697              1315            1315          558      11     False  False
# 550              3690            3690          170   13666     False  False
# 544              1421            1421          156    1135     False  False
# 339              1647            1647          424      36     False  False
# 151              8118            8118         1645    1716     False  False
# 876              1156            1156          433      11     False  False
# 492              1432            1432          327      13     False  False
# 40               2048            2048           55       8     False  False
# 989              2128            2128          526    7080     False  False
# 548              1415            1415          188  110463     False  False
# 786              2646            2646          232     763     False  False
# 625              1366            1366          194      26     False  False
# 852              1170            1170          453     175     False  False
# 353              5099            5099          971   21634      True  False
# 318              1676            1676          754   92115     False  False
# 642              3133            3133           87      84     False  False
# 685              1321            1321          331  313067     False  False
# 569              3611            3611         1588  141867     False  False
# 363              1617            1617          229      38     False  False
# 241              6372            6372         1388   36271     False  False
# 796              1206            1206          156     379     False  False
# 421              1504            1504          378    1929     False  False
# 148              8178            8178          993    2166     False  False
# 760              2743            2743          103       7     False  False

# %%
exp1 = df.sort_values("size", ascending=True)[:50][-20:]
exp1
# Out:
#                                full_name language  commits  stargazers_count  \
# 725                  kragniz/json-sempai   Python       86              1252
# 190    careercup/CtCI-6th-Edition-Python   Python       56              1797
# 614              eth0izzle/bucket-stream   Python       35              1372
# 356                matthewearl/deep-anpr   Python       40              1625
# 32                   joshnewlan/say_what   Python       18              2063
# 134                      arc90/git-sweep   Python       18              1870
# 728           llSourcell/learn_math_fast   Python        5              2822
# 859  openai/evolution-strategies-starter   Python        4              1165
# 297        fchollet/deep-learning-models   Python       22              5714
# 617                spyoungtech/grequests   Python       75              3213
# 853                             edc/bass   Python       84              1170
# 983                meijieru/crnn.pytorch   Python       17              1137
# 644                 vulnersCom/getsploit   Python       33              1352
# 555                   floydhub/dl-docker   Python       53              3664
# 144                     bitly/data_hacks   Python       50              1859
# 795                     kevinburke/hamms   Python       58              1206
# 825                jlsutherland/doc2text   Python       61              1197
# 588                     reinderien/mimic   Python       86              3536
# 182                      danijar/handout   Python       45              1806
# 371   guillaumegenthial/sequence_tagging   Python       37              1599
#
#      watchers_count  forks_count  size  archived   fork
# 725            1252           54    39     False  False
# 190            1797          749    40     False  False
# 614            1372          157    41     False  False
# 356            1625          672    42     False  False
# 32             2063          124    43     False  False
# 134            1870          105    43     False  False
# 728            2822          550    44     False  False
# 859            1165          226    44     False  False
# 297            5714         1879    45     False  False
# 617            3213          297    45     False  False
# 853            1170           40    46     False  False
# 983            1137          375    46     False  False
# 644            1352          212    47     False  False
# 555            3664          818    47     False  False
# 144            1859          186    50     False  False
# 795            1206           30    50     False  False
# 825            1197           93    51     False  False
# 588            3536          102    52     False  False
# 182            1806           92    55     False  False
# 371            1599          619    56     False  False

# %%
def x1(s):
    s = s.replace("/", "_")
    return s

# %%
for l in list(map(lambda x: f"https://github.com/{x}.git", exp1.full_name.values.tolist())):
    print(l)
# Out:
# https://github.com/kragniz/json-sempai.git
# https://github.com/careercup/CtCI-6th-Edition-Python.git
# https://github.com/eth0izzle/bucket-stream.git
# https://github.com/matthewearl/deep-anpr.git
# https://github.com/joshnewlan/say_what.git
# https://github.com/arc90/git-sweep.git
# https://github.com/llSourcell/learn_math_fast.git
# https://github.com/openai/evolution-strategies-starter.git
# https://github.com/fchollet/deep-learning-models.git
# https://github.com/spyoungtech/grequests.git
# https://github.com/edc/bass.git
# https://github.com/meijieru/crnn.pytorch.git
# https://github.com/vulnersCom/getsploit.git
# https://github.com/floydhub/dl-docker.git
# https://github.com/bitly/data_hacks.git
# https://github.com/kevinburke/hamms.git
# https://github.com/jlsutherland/doc2text.git
# https://github.com/reinderien/mimic.git
# https://github.com/danijar/handout.git
# https://github.com/guillaumegenthial/sequence_tagging.git

# %%
list(map(lambda x: f"/tmp/repositories/{x1(x)}", exp1.full_name.values.tolist()))
# Out:
# ['/tmp/repositories/spyder-ide_spyder',
#  '/tmp/repositories/cloudera_hue',
#  '/tmp/repositories/translate_pootle',
#  '/tmp/repositories/divio_django-cms',
#  '/tmp/repositories/stamparm_maltrail',
#  '/tmp/repositories/trustedsec_social-engineer-toolkit',
#  '/tmp/repositories/matrix-org_synapse',
#  '/tmp/repositories/Tribler_tribler',
#  '/tmp/repositories/cupy_cupy',
#  '/tmp/repositories/conda_conda',
#  '/tmp/repositories/Komodo_KomodoEdit',
#  '/tmp/repositories/wbond_package_control_channel',
#  '/tmp/repositories/openshift_openshift-ansible',
#  '/tmp/repositories/mirumee_saleor',
#  '/tmp/repositories/nltk_nltk',
#  '/tmp/repositories/readthedocs_readthedocs.org',
#  '/tmp/repositories/RasaHQ_rasa',
#  '/tmp/repositories/biopython_biopython',
#  '/tmp/repositories/spack_spack',
#  '/tmp/repositories/pritunl_pritunl']

# %%
"/".replace()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-67594560f40a> in <module>
# ----> 1 "/".replace(in_place=True)
#
# TypeError: replace() takes no keyword arguments

# %%
git clone https://github.com/ishepard/pydriller.git /tmp/repositories/
