# %%
import sys
sys.path.append("../")

# %%
from tqdm import tqdm_notebook

import os
import re
import orjson
import github
import typing
import jsonlines

import pandas as pd
import numpy as np

# %%
JSONType = typing.Dict[str, typing.Any]

# %% [markdown]
# ## Load a data batch to analyze

# %%
def iterate_lines(file_path: str) -> typing.Generator[str, None, None]:
    with open(file_path, mode="r") as ptr:
        while True:
            line = ptr.readline()
            if not line:
                return
            yield line

# %%
file_path = "../tmp/raw_dataset.jsonl"

# %%
def remove_diffs_from_line(line: str) -> JSONType:
    json = orjson.loads(line)
    for modification in json["modifications"]:
        modification["diff"] = None
    return json

# %%
remove_diffs_from_line(next(iterate_lines(file_path)))
# Out:
# {'sha': '74a04f01f662b4611d9aed44a77041a982b8766c',
#  'repository': 'facebookresearch@pythia',
#  'message': 'Initial commit',
#  'modifications': [{'added': 9,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': '.gitignore',
#    'old_path': None,
#    'new_path': '.gitignore'},
#   {'added': 71,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'Dockerfile',
#    'old_path': None,
#    'new_path': 'Dockerfile'},
#   {'added': 30,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'LICENSE',
#    'old_path': None,
#    'new_path': 'LICENSE'},
#   {'added': 269,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'README.md',
#    'old_path': None,
#    'new_path': 'README.md'},
#   {'added': 1,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'best_model_predict_test.json',
#    'old_path': None,
#    'new_path': 'best_model/best_model_predict_test.json'},
#   {'added': 86,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'config.yaml',
#    'old_path': None,
#    'new_path': 'best_model/config.yaml'},
#   {'added': 55,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'collections.py',
#    'old_path': None,
#    'new_path': 'config/collections.py'},
#   {'added': 99,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'config.py',
#    'old_path': None,
#    'new_path': 'config/config.py'},
#   {'added': 131,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'config_utils.py',
#    'old_path': None,
#    'new_path': 'config/config_utils.py'},
#   {'added': 86,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'config.yaml',
#    'old_path': None,
#    'new_path': 'config/demo/config.yaml'},
#   {'added': 170,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'function_config_lib.py',
#    'old_path': None,
#    'new_path': 'config/function_config_lib.py'},
#   {'added': 48,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'MFH_ft.yaml',
#    'old_path': None,
#    'new_path': 'config/keep/MFH_ft.yaml'},
#   {'added': 23,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'detectron.yaml',
#    'old_path': None,
#    'new_path': 'config/keep/detectron.yaml'},
#   {'added': 95,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'MFH_module.yaml',
#    'old_path': None,
#    'new_path': 'config/verbose/MFH_module.yaml'},
#   {'added': 88,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'dectectron_finetune.yaml',
#    'old_path': None,
#    'new_path': 'config/verbose/dectectron_finetune.yaml'},
#   {'added': 86,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'default.yaml',
#    'old_path': None,
#    'new_path': 'config/verbose/default.yaml'},
#   {'added': 51,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'config_help.md',
#    'old_path': None,
#    'new_path': 'config_help.md'},
#   {'added': 0,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'COCO_test2015_000000000001.npy',
#    'old_path': 'data/demo/features/COCO_test2015_000000000001.npy',
#    'new_path': 'data/demo/features/COCO_test2015_000000000001.npy'},
#   {'added': 0,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'COCO_test2015_000000000001.jpg',
#    'old_path': 'data/demo/images/COCO_test2015_000000000001.jpg',
#    'new_path': 'data/demo/images/COCO_test2015_000000000001.jpg'},
#   {'added': 0,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'imdb_demo.npy',
#    'old_path': 'data/demo/imdb/imdb_demo.npy',
#    'new_path': 'data/demo/imdb/imdb_demo.npy'},
#   {'added': 53,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'data_preprocess.md',
#    'old_path': None,
#    'new_path': 'data_prep/data_preprocess.md'},
#   {'added': 148,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'build_vqa_2.0_imdb.py',
#    'old_path': None,
#    'new_path': 'data_prep/vqa_v2.0/build_vqa_2.0_imdb.py'},
#   {'added': 57,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'download_vqa_2.0.sh',
#    'old_path': None,
#    'new_path': 'data_prep/vqa_v2.0/download_vqa_2.0.sh'},
#   {'added': 49,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'extract_ques_info.py',
#    'old_path': None,
#    'new_path': 'data_prep/vqa_v2.0/extract_ques_info.py'},
#   {'added': 65,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'extract_vocabulary.py',
#    'old_path': None,
#    'new_path': 'data_prep/vqa_v2.0/extract_vocabulary.py'},
#   {'added': 67,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'extract_word_glove_embedding.py',
#    'old_path': None,
#    'new_path': 'data_prep/vqa_v2.0/extract_word_glove_embedding.py'},
#   {'added': 0,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'genome_ids.pkl',
#    'old_path': 'data_prep/vqa_v2.0/genome_ids.pkl',
#    'new_path': 'data_prep/vqa_v2.0/genome_ids.pkl'},
#   {'added': 197,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'process_answers.py',
#    'old_path': None,
#    'new_path': 'data_prep/vqa_v2.0/process_answers.py'},
#   {'added': 82789,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'train_ids.pkl',
#    'old_path': None,
#    'new_path': 'data_prep/vqa_v2.0/train_ids.pkl'},
#   {'added': 40510,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'val_ids.pkl',
#    'old_path': None,
#    'new_path': 'data_prep/vqa_v2.0/val_ids.pkl'},
#   {'added': 8,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': '__init__.py',
#    'old_path': None,
#    'new_path': 'dataset_utils/__init__.py'},
#   {'added': 22,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'create_imdb_header.py',
#    'old_path': None,
#    'new_path': 'dataset_utils/create_imdb_header.py'},
#   {'added': 312,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'dataSet.py',
#    'old_path': None,
#    'new_path': 'dataset_utils/dataSet.py'},
#   {'added': 52,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'text_processing.py',
#    'old_path': None,
#    'new_path': 'dataset_utils/text_processing.py'},
#   {'added': 18,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'utils.py',
#    'old_path': None,
#    'new_path': 'dataset_utils/utils.py'},
#   {'added': 15,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'vqa_collates.py',
#    'old_path': None,
#    'new_path': 'dataset_utils/vqa_collates.py'},
#   {'added': 16,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'vqa_concate_dataset.py',
#    'old_path': None,
#    'new_path': 'dataset_utils/vqa_concate_dataset.py'},
#   {'added': 77,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'vqa_html_writer.py',
#    'old_path': None,
#    'new_path': 'dataset_utils/vqa_html_writer.py'},
#   {'added': 78,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'ensemble.py',
#    'old_path': None,
#    'new_path': 'ensemble.py'},
#   {'added': 47,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'eval_demo.py',
#    'old_path': None,
#    'new_path': 'eval_model/eval_demo.py'},
#   {'added': 294,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'vqaEval.py',
#    'old_path': None,
#    'new_path': 'eval_model/vqaEval.py'},
#   {'added': 8,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': '__init__.py',
#    'old_path': None,
#    'new_path': 'global_variables/__init__.py'},
#   {'added': 22,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'global_variables.py',
#    'old_path': None,
#    'new_path': 'global_variables/global_variables.py'},
#   {'added': 0,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'code_structure_plot.png',
#    'old_path': 'info/code_structure_plot.png',
#    'new_path': 'info/code_structure_plot.png'},
#   {'added': 0,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'pythia.jpg',
#    'old_path': 'info/pythia.jpg',
#    'new_path': 'info/pythia.jpg'},
#   {'added': 0,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'vqa_example.png',
#    'old_path': 'info/vqa_example.png',
#    'new_path': 'info/vqa_example.png'},
#   {'added': 11,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'install.sh',
#    'old_path': None,
#    'new_path': 'install.sh'},
#   {'added': 64,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'run_test.py',
#    'old_path': None,
#    'new_path': 'run_test.py'},
#   {'added': 123,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'convert_VD_to_COCO_qa.py',
#    'old_path': None,
#    'new_path': 'tools/convert_VD_to_COCO_qa.py'},
#   {'added': 230,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'convert_VG_to_COCO.py',
#    'old_path': None,
#    'new_path': 'tools/convert_VG_to_COCO.py'},
#   {'added': 57,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'convert_VG_to_COCO_qa.py',
#    'old_path': None,
#    'new_path': 'tools/convert_VG_to_COCO_qa.py'},
#   {'added': 62,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'convert_tsv_feature_to_indiv.py',
#    'old_path': None,
#    'new_path': 'tools/convert_tsv_feature_to_indiv.py'},
#   {'added': 66,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'eval_ensemble_on_val.py',
#    'old_path': None,
#    'new_path': 'tools/eval_ensemble_on_val.py'},
#   {'added': 29,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'extract_detectron_weights.py',
#    'old_path': None,
#    'new_path': 'tools/extract_detectron_weights.py'},
#   {'added': 40,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'extract_minival_ids.py',
#    'old_path': None,
#    'new_path': 'tools/extract_minival_ids.py'},
#   {'added': 88,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'extract_visual_features_vgg_pool5.py',
#    'old_path': None,
#    'new_path': 'tools/extract_visual_features_vgg_pool5.py'},
#   {'added': 40,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'generate_minival_annotation.py',
#    'old_path': None,
#    'new_path': 'tools/generate_minival_annotation.py'},
#   {'added': 38,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'mirror_images.py',
#    'old_path': None,
#    'new_path': 'tools/mirror_images.py'},
#   {'added': 16,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'model_path.py',
#    'old_path': None,
#    'new_path': 'tools/model_path.py'},
#   {'added': 206,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'process_log.py',
#    'old_path': None,
#    'new_path': 'tools/process_log.py'},
#   {'added': 37,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'rename_genome_file.py',
#    'old_path': None,
#    'new_path': 'tools/rename_genome_file.py'},
#   {'added': 83,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'subset_val.py',
#    'old_path': None,
#    'new_path': 'tools/subset_val.py'},
#   {'added': 23,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'timer.py',
#    'old_path': None,
#    'new_path': 'tools/timer.py'},
#   {'added': 129,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'visualize_bbox.py',
#    'old_path': None,
#    'new_path': 'tools/visualize_bbox.py'},
#   {'added': 77,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'classifier.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/classifier.py'},
#   {'added': 160,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'image_attention.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/image_attention.py'},
#   {'added': 66,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'image_embedding.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/image_embedding.py'},
#   {'added': 57,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'image_feature_encoding.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/image_feature_encoding.py'},
#   {'added': 23,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'intermediate_layer.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/intermediate_layer.py'},
#   {'added': 173,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'multi_modal_combine.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/multi_modal_combine.py'},
#   {'added': 71,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'nonlinear_layer.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/nonlinear_layer.py'},
#   {'added': 65,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'post_combine_transform.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/post_combine_transform.py'},
#   {'added': 104,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'question_embeding.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/question_embeding.py'},
#   {'added': 115,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'top_down_bottom_up_model.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/top_down_bottom_up_model.py'},
#   {'added': 136,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'unittests.py',
#    'old_path': None,
#    'new_path': 'top_down_bottom_up/unittests.py'},
#   {'added': 239,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'train.py',
#    'old_path': None,
#    'new_path': 'train.py'},
#   {'added': 252,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'Engineer.py',
#    'old_path': None,
#    'new_path': 'train_model/Engineer.py'},
#   {'added': 115,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'Error_analysis.py',
#    'old_path': None,
#    'new_path': 'train_model/Error_analysis.py'},
#   {'added': 122,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'Loss.py',
#    'old_path': None,
#    'new_path': 'train_model/Loss.py'},
#   {'added': 8,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': '__init__.py',
#    'old_path': None,
#    'new_path': 'train_model/__init__.py'},
#   {'added': 86,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'dataset_utils.py',
#    'old_path': None,
#    'new_path': 'train_model/dataset_utils.py'},
#   {'added': 31,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'eval_utils.py',
#    'old_path': None,
#    'new_path': 'train_model/eval_utils.py'},
#   {'added': 48,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'evaluate.py',
#    'old_path': None,
#    'new_path': 'train_model/evaluate.py'},
#   {'added': 164,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'evaluate_with_ensemble.py',
#    'old_path': None,
#    'new_path': 'train_model/evaluate_with_ensemble.py'},
#   {'added': 85,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'helper.py',
#    'old_path': None,
#    'new_path': 'train_model/helper.py'},
#   {'added': 104,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'model_factory.py',
#    'old_path': None,
#    'new_path': 'train_model/model_factory.py'},
#   {'added': 136,
#    'removed': 0,
#    'change_type': 'ADD',
#    'diff': None,
#    'filename': 'vqa_demo.ipynb',
#    'old_path': None,
#    'new_path': 'vqa_demo.ipynb'}]}

# %%
def filter_obj(obj: JSONType) -> JSONType:
    return {
        "sha": obj["sha"],
        "message": obj["message"],
        "modifications": len(obj["modifications"])
    }

def remove_diffs_from_file(file_path: str, output_path: str = None, max_len: int = 100_000):
    buffer: typing.List[JSONType] = []
    for line in iterate_lines(file_path):
        obj = remove_diffs_from_line(line)
        obj = filter_obj(obj)
        buffer.append(obj)
        if len(buffer) >= max_len:
            return buffer
    return buffer

# %%
data = remove_diffs_from_file(file_path, max_len=100_000)

# %%
df = pd.DataFrame(data)
df
# Out:
#                                             sha  \
# 0      74a04f01f662b4611d9aed44a77041a982b8766c
# 1      af0a1b48fd77d6581231fa1d7d1e935b4d039f15
# 2      7d0548bb561c96920d17767c38edded301c81d39
# 3      4520567675b4ece4fe2f0457aa0def752c23fdd4
# 4      beb0ae07e487b86ff8bf9d24d67123a408b2a378
# ...                                         ...
# 99995  ae97ca1dc83848e40b0609a49eee0eb92e43570f
# 99996  0259ca814dbee9d5a7cf2930b610264e96d1d6d8
# 99997  4d47de6f362ebb9d745475e84ee0a2d22b3a5b0c
# 99998  a6996a201a96c7d7c4aa84cf9af77f5fbfde9fb3
# 99999  af3fe7574b8ff1a137660d854d432ec635630e96
#
#                                                  message  modifications
# 0                                         Initial commit             87
# 1                                       Update README.md              1
# 2                                   add acknowledgements              1
# 3                adding code_of_conduct and contributing              3
# 4      allow to load pretrained multiple GPU model un...              1
# ...                                                  ...            ...
# 99995  Use update_one instead of replace_one in mongo...              1
# 99996  Add stalebot integration\n\nAs some issue tend...              1
# 99997                 Add reference to incense in README              3
# 99998  fix exception with compiled pybind11 extension...              1
# 99999  Add SO link to README\n\nAdd a small section i...              1
#
# [100000 rows x 3 columns]

# %% [markdown]
# ## Modification count statistics

# %%
df.modifications.mean(), \
df.modifications.median(), \
df.modifications.max()
# Out:
# (2.7774, 1.0, 18337)

# %%
df.modifications.quantile(0.15), \
df.modifications.quantile(0.25), \
df.modifications.quantile(0.50), \
df.modifications.quantile(0.75), \
df.modifications.quantile(0.95)
# Out:
# (0.0, 1.0, 1.0, 2.0, 7.0)

# %%
df[df.modifications == 77983]
# Out:
#                                              sha  \
# 509774  c2d6d44438b5d23393afd13ddd80cd933cc00099
#
#                                        message  modifications
# 509774  Massive rework of the whole repository          77983

# %% [markdown]
# ## Explore message insights

# %%
df[df.message.str.contains("merge", flags=re.IGNORECASE, regex=True)]
# Out:
#                                             sha  \
# 14     49bf5f677c36baedb4d8fa53f665bd97dbaeb1b8
# 18     e942e94fae8ef3fe5d93f4bb3d25daf6b9e0eaa2
# 25     5ad666f417684f8f1280029ac46e19dc8b5ddb0a
# 364    c8ef41ef4723f371e9c8759f0fb396a507737098
# 394    b31cb7d03f687021c9ea334f35acdcb6d34305d5
# ...                                         ...
# 99974  6faaa8bc08fe8f0f8fe31cdfecb42b4e2af6c24c
# 99976  c8e570fed38dce37580a12bfec4ca2e4ddf0ccb7
# 99982  b738fa6222661d109c340ca115c5a89e00557020
# 99983  94785b9592b16e8498212ad9cfa0e05d49a1819d
# 99989  0948cd10831538dbfad990bf5996d6420ad710fa
#
#                                                  message  modifications
# 14     Merge pull request #7 from meetshah1995/master...              0
# 18     Merge pull request #9 from Cadene/master\n\nFi...              0
# 25     Merge pull request #39 from HuaizhengZhang/pat...              0
# 364    Merge remote-tracking branch 'origin/master'\n...              0
# 394    Merge pull request #1 from Radagaisus/patch-1\...              0
# ...                                                  ...            ...
# 99974  Merge pull request #367 from thequilo/improved...              0
# 99976  Merge pull request #372 from onurgu/master\n\n...              0
# 99982  Merge pull request #373 from bosr/feat/use-col...              0
# 99983  Merge pull request #374 from brickerino/master...              0
# 99989  Merge branch 'master' of https://github.com/on...              0
#
# [18018 rows x 3 columns]

# %%
df[df.message.str.contains("^bump", flags=re.IGNORECASE, regex=True)][30:60]
# Out:
#                                            sha  \
# 3352  acb11bd45fc153ea37278efb7683555df17f4215
# 3398  e91c46bd16c67b740ff17ec1d5eb8c3ba3611d4e
# 3402  5da6f63ceaac29896f3d54004462ab23b1ef4e16
# 3443  357c790844379f54ac133b8b47e90daf6b34327e
# 3450  f9712a4f0f21fb71c83097a73845dfabfadb42ce
# 3489  dbf19845a2bfd4f869cd7d17a7b8bcb63afd7a7e
# 3540  605a1b8b42658a27e8381c8ff9b9d2225e3d39d2
# 3632  c87e7c6274da5eff5a0283b28570a78cc9975610
# 3638  1745e1bd287b65d7d734b925660647533971193b
# 3676  346bdf5d71608142b5f0d7185790e4429e01e322
# 3677  796c15aa04c50d970aa52006ef149bd783b28511
# 5035  3ef68e6af9fd36371addbeb5a9a923290196931a
# 5122  cb11d0b041c844ca521cd113c834d9dd153d25b8
# 5247  0f354523b8f7ff1ae9ab1ae1cf1d241a3da46db9
# 5343  ed26eb070589d777d526b68c0cd60ef18222c482
# 5345  86d507dc3d43951d984bc04cfa6b59cadd615b6e
# 5886  547e9f7540f835fe097c618af7072ccf0abd8c53
# 5935  0a92fba61dcddfed699f9f0901780dc2f7249a66
# 6231  a139d1ccc00137fe3983de1ffdb1f2d6f64a7cd0
# 6429  aaba5bd64a3df6d4cacb4a5eac03abef07b7e910
# 6508  cc27aaf7b79f2eadd2927d566ebaf913fda66f3c
# 6511  76c0beb75da3132b9c158d793cc7094480c751c4
# 6567  38aedba0b3fd3d2c913a8e284e7075748fdfcfed
# 6627  a84b86c856d3e0b244f24504a53a6fdd54f959b4
# 6659  b3c1020175f7a07c611384eae9f2089e2249a425
# 6763  3c83e77c5a5a80a27eeb65ff2f32e71e6a9ccf74
# 6824  624f0c632d45049143a9ae6f54be4188facd166a
# 6825  dca1656b428feb42bc030b6d4b88997c26dbbf3a
# 6854  15681f455d2d55eda641a4769d4809762b037784
# 7030  a8c21e4a4d4dd7246485dd56a6cf4c217353c894
#
#                                                 message  modifications
# 3352                             Bumped version to dev0              1
# 3398                                   Bumped CHANGELOG              1
# 3402               Bumped CHANGELOG with recent changes              1
# 3443                             Bumped version to dev0              1
# 3450                       Bumped CHANGELOG and AUTHORS              2
# 3489   Bumped CHANGELOG, added Aleš to AUTHORS. Thanks!              2
# 3540                                   Bumped CHANGELOG              1
# 3632                                   Bumped changelog              1
# 3638  Bumped required package jsonfield to version 0...              1
# 3676  Bumping changelog and version number for release.              2
# 3677        Bumping version and CHANGELOG post-release.              2
# 5035                              Bump to version 0.2.1              1
# 5122                           bump to version 0.9.0rc3              1
# 5247                                      Bump to 0.9.0              8
# 5343                                      Bump to 0.9.1              1
# 5345                              Bump to version 0.9.1              1
# 5886                              Bump to version 0.9.2              2
# 5935                              bump to version 0.9.3              2
# 6231                                   bump to 0.10.rc1              1
# 6429                           Bump to version 0.10.rc3              2
# 6508                           Bump to version 0.10.rc4              1
# 6511                           Bump to version 0.10.rc4              1
# 6567                             Bump to version 0.10.1              2
# 6627                             Bump to version 0.10.2              2
# 6659                            Bump to data version 11              1
# 6763                                   bump to 0.11.dev              1
# 6824                               Bump to version 0.11              2
# 6825                               Bump to version 0.11              3
# 6854                             Bump to version 0.11.1              3
# 7030                                     bump to 0.11.2              2

# %%
df[df.message.str.contains("^initial(\s+\w+){0,3}$", flags=re.IGNORECASE, regex=True)]
# Out:
#                                              sha  \
# 0       74a04f01f662b4611d9aed44a77041a982b8766c
# 329     bfb28da372a8fd8fc1b93378c8530472cc0ca483
# 429     d46ec12f47e75ab7a34410d37d63906c99fe3b8f
# 634     a9102f42db200ae3d21486c2a97b98338ee65b2b
# 2320    83b1847647c08d089a477fd8441cc57737292e12
# ...                                          ...
# 992361  eb082e22b8431ff9e2b6ac3c776a1f83e7150453
# 993129  58680f38c3642c9c495bdf2809c370c5f647e1f3
# 993560  7821b24144e6709b1febd3986a5f1a47c8898854
# 994632  ccf4199ac8b453227e6ea73f5465ce69782ceab0
# 994703  017c9d07d2893963976befec4bb15ac0135613c0
#
#                                  message  modifications
# 0                         Initial commit             87
# 329                       Initial commit              3
# 429                       Initial commit              3
# 634          initial version of reactive              2
# 2320                      initial commit              6
# ...                                  ...            ...
# 992361      initial arista module import              4
# 993129        Initial bigip_node version              1
# 993560      initial ejabberd_user module              1
# 994632  Initial commit of rax_dns_record              1
# 994703     Initial commit of rax_keypair              1
#
# [921 rows x 3 columns]

# %%
df[df.message.str.contains("^update(\s+\w+){0,3}$", flags=re.IGNORECASE, regex=True)]
# Out:
#                                              sha  \
# 19      18cd8b9c23db229d8e0e55b0a6c2d337cb66d2e3
# 129     543e5ad91bb5e51573f33eb7154883fb128a8379
# 202     efb74335645b78e49b6d09813f292e6828235b9e
# 232     41c9b8b11844037bcd825b863fc42150aad06354
# 415     4db83916751aed54efa7a8f6d8264e8e893560b9
# ...                                          ...
# 999781  97438f003909361d21a12a4187bbceb50fe1387a
# 999797  019f74dcedc598c31cb7109d82768e617115a232
# 999820  9db17afc855532b87675eaeee5f0b032d8e92041
# 999898  dd484e82111e2856af0dbcf6c48f2385743cbd63
# 999927  d0556885ff8cad8d0899757a0132a360a44d272c
#
#                                 message  modifications
# 19                Update download paths              1
# 129                      Update configs              4
# 202         Update COC and Contributing              2
# 232     Update quickstart documentation              1
# 415                       update readme              1
# ...                                 ...            ...
# 999781               Update the modules              3
# 999797                   Update modules              4
# 999820                   Update modules              4
# 999898                   Update modules              3
# 999927                   Update modules              1
#
# [13105 rows x 3 columns]

# %%
df.modifications.mean()
# Out:
# 3.496965

# %%
def clean_dataset(df: pd.DataFrame) -> pd.DataFrame:
    df = df[~df.message.str.contains("merge", flags=re.IGNORECASE, regex=True)]
    df = df[~df.message.str.contains("^\W*(\w+(\W+|$)){0,3}$", regex=True)]
    return df

# %%
clean_dataset(df)
# Out:
#                                              sha  \
# 3       4520567675b4ece4fe2f0457aa0def752c23fdd4
# 4       beb0ae07e487b86ff8bf9d24d67123a408b2a378
# 5       bf29c7cd19aaf290f4efdcd70b8c61c68987dd43
# 11      c862901d805bcca2dd18d6765ac73afcd9591797
# 12      01e40789b4326be1b4335e81cf20b72f922fc0db
# ...                                          ...
# 999992  2e929cf0cee26addecff9b129d1c6b82f6ea5cd8
# 999993  2dc910bd1486ab27bb3f7cf9c52f3dec75448ce5
# 999994  b9bfb22a9dab2592c16388bc70db320bda7ff209
# 999997  b9aa8f07bebcdb7a448154a7c773ef173ab3c73f
# 999999  920b71984e75f5f78a358fc2865d40b6c3269ba7
#
#                                                   message  modifications
# 3                 adding code_of_conduct and contributing              3
# 4       allow to load pretrained multiple GPU model un...              1
# 5                             add standalone image vqa nb              3
# 11      reformating the detectron feature extractor, f...              1
# 12      removing duplicating detectron feature extractor.              1
# ...                                                   ...            ...
# 999992  Fixes bug #10281 - Trailing zeros were truncat...              1
# 999993  Fixes bug #10225 - Runtime error\n\nPrevents a...              1
# 999994                            fix https transport bug              1
# 999997  skips certain ssh errors and attempts to conti...              1
# 999999  lists => frozenset as we're only using them in...              2
#
# [654191 rows x 3 columns]

# %%
df[df.message.str.contains("fix", flags=re.IGNORECASE, regex=True)]
# Out:
#                                              sha  \
# 16      9599ee6508727fa67beb14c5c74ecf38d9bf291c
# 18      e942e94fae8ef3fe5d93f4bb3d25daf6b9e0eaa2
# 44      14d066d2b0f4cf205056af51cbad1420b3525855
# 49      fbbfb42c5264bd716a6883b0022218ef8b24daf4
# 50      54f43f1c9ccf1c45abb7d28472752350d86964fa
# ...                                          ...
# 999991  a14248ffe1ec7a7cf8623732ebc24e680883fa20
# 999992  2e929cf0cee26addecff9b129d1c6b82f6ea5cd8
# 999993  2dc910bd1486ab27bb3f7cf9c52f3dec75448ce5
# 999994  b9bfb22a9dab2592c16388bc70db320bda7ff209
# 999997  b9aa8f07bebcdb7a448154a7c773ef173ab3c73f
#
#                                                   message  modifications
# 16                     Fix one_stage_run_model args order              1
# 18      Merge pull request #9 from Cadene/master\n\nFi...              0
# 44        Updates for package init and other syntax fixes             18
# 49                  Config related changes and soem fixes              6
# 50      Bug fixes for variety of syntax error and more...             13
# ...                                                   ...            ...
# 999991  Fixes bug #10281 - Trailing zeros were truncat...              1
# 999992  Fixes bug #10281 - Trailing zeros were truncat...              1
# 999993  Fixes bug #10225 - Runtime error\n\nPrevents a...              1
# 999994                            fix https transport bug              1
# 999997  skips certain ssh errors and attempts to conti...              1
#
# [209826 rows x 3 columns]

# %%
df[df.message.str.contains("([^\d]|^)\d([^\d]|$)", flags=re.IGNORECASE, regex=True)][:40]
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                                           sha  \
# 14   49bf5f677c36baedb4d8fa53f665bd97dbaeb1b8
# 18   e942e94fae8ef3fe5d93f4bb3d25daf6b9e0eaa2
# 25   5ad666f417684f8f1280029ac46e19dc8b5ddb0a
# 33   5714ac561bfe7def6535ce35e365131ebd174a55
# 72   cd323fc59e694b6f27a3cbe81cd03e7e2805b30c
# 76   75f8694219c60dfd59e481df1d526ab3efa372e9
# 86   1451d9a5e0823de5ab16ba4999d3fdc55ec32ba3
# 123  56117ea05028cb075ef6e70780426621efc07439
# 144  eb64a23f951829a4260c9a461a1de7d7ab643b5c
# 154  5c11419fdfb9ab87e19e002fbc58ffff75b7d585
# 163  af82140e11ac1a510c90193e7d644173b5410a01
# 168  18f8cdafa8319de4212714b5f719f00a05788022
# 171  1ad11a0d939fd110a537670056b80dfaa647ff59
# 216  7718393251a0dab14b56f0628f2950090d9ec9fe
# 256  099146dfa1348db766c6be25565c8f85e51be749
# 286  2a2588a249e1c4a08b2ddc1eeb97a8ec8b4d0bd7
# 288  6586b3e358b40d7b8edfac378f5f5e050bcdd0a4
# 290  0bf4026c39e7b5771f3beb19875c6dcc498c65c4
# 292  a122cc52814b70e5130e462791bfe09fef30aacf
# 300  6fc1160cd38f08c8f2b06a4b4bd58193e5ff7e60
# 319  a3dc67b5bf84560ede32ef33d5b9f461b1bdd343
# 328  b201c6b035e4b52e3d2612d582bd71875852e35b
# 394  b31cb7d03f687021c9ea334f35acdcb6d34305d5
# 398  7141b28d494421922adf8616b8bb4cfc5cd219d8
# 403  4e1ad5893a9379a1f260e7a33653cfd57c6bf817
# 404  6dc6623e2b233508792a9d1dd0404b9d55d41c94
# 408  cdc5fa53e86e7cad4bc011153cd83a3a310324f9
# 413  87c83c44a45fc9233415d9a56c56d5cacc141b20
# 414  3840e7c877034bdd5b9ced96d460ba6f42ce9b7a
# 418  7c13895b809ff2d1fb558797bddc129c03b628f9
# 420  58d253d3c4ec99416c096f174d171cecb3b6965d
# 423  b37db1a8ba8425cdda03cb4628069d8a11e2659b
# 424  ac200a54eb65ae6b902be200d5f631ee26be10b4
# 425  998f39bf2786980e3e3b171e9796148a3ec3322f
# 437  d845754010d427e93ed9506cb4c3c65c31292085
# 439  611f5f340c9e12153b4106c95f64bd149c247416
# 442  180bf8d644bfb84bc8f273ff24bd16df3b14a01c
# 448  14365e4e7d3d6f5c63aa07ab0d1452220a4b27da
# 449  a046b602d82f4e0fad80992cb9b9fb08b98ae84e
# 452  0c281576afefcc207b17b950f14814cf626e008f
#
#                                                message  modifications
# 14   Merge pull request #7 from meetshah1995/master...              0
# 18   Merge pull request #9 from Cadene/master\n\nFi...              0
# 25   Merge pull request #39 from HuaizhengZhang/pat...              0
# 33   Add tasks folder with vqa2 task built on base ...              4
# 72                            Add best config for VQA2              1
# 76   Revert imdb builder, add metrics info to vqa2 ...              3
# 86   Update registry to register metrics and suppor...              1
# 123  End 2 End working vizwiz model and add model r...              9
# 144  Update losses and metrics to include info\n\n-...              2
# 154                   Add vqa2 ocr dataset and builder              2
# 163  Add tests for utils (#5)\n\n* Add preprocessin...              4
# 168                         Add ban config for VQAv2.0              1
# 171  Add support for Bert Embeddings and misc restr...              7
# 216  Init answer indices in VQAAnswerProcessor with...              1
# 256  Fix ocr based configs and add LoRRA configs fo...              6
# 286      [docs] Adding md5 checksum for large tarballs              1
# 288  [fixes] Fix initialization of top down bottom ...              1
# 290  [tests] CircleCI: Lint code for undefined name...              5
# 292  [docs] Add pretrained models for vizwiz model\...              4
# 300  [feature] Adding Image captioning to Pythia (#...             16
# 319  [fix] Fix extract_features_vmb.py and extract_...              2
# 328  Bump nltk from 3.4.1 to 3.4.5 (#192)\n\nBumps ...              1
# 394  Merge pull request #1 from Radagaisus/patch-1\...              0
# 398  Merge pull request #2 from ZidanMusk/master\n\...              0
# 403  Merge pull request #3 from MG2033/master\n\nfi...              0
# 404  Merge pull request #1 from Mrgemy95/master\n\n...              0
# 408  Merge pull request #4 from ZidanMusk/master\n\...              0
# 413  Merge pull request #7 from 3ammor/patch-1\n\nU...              0
# 414  Merge pull request #8 from 3ammor/patch-2\n\nU...              0
# 418                                     update readme2              1
# 420  Merge pull request #10 from waleedmohamedme/pa...              0
# 423                             fix some utils bugs v2              3
# 424         Fixed typos and spacing according to PEP 8             12
# 425  Merge pull request #16 from Ahmkel/master\n\nF...              0
# 437  Merge pull request #1 from zoofIO/travis\n\ntr...              0
# 439      Fixes for Py 3.2 and PyQt4 (on Raspberrie Pi)              2
# 442  Add zoof.qt plus tests for it.\n\nTaken from p...              4
# 448  First stab at a light-weight, pure Python GUI ...              8
# 449                  WIP for launching HTML5 runtimes.              7
# 452                      init html5 runtime subpackage              4
