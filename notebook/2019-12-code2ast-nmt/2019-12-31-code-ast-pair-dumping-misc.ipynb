# %%
import sys
sys.path.append("/workspace")

# %% [markdown]
# # Test AST parser utils

# %%
from src.ast_parser import ASTParser, LanguageRepr

# %%
lang_repr = LanguageRepr(
    library_path="/workspace/tmp/ast_test/my-languages.so", lang="python"
)

parser = ASTParser(lang_repr)

# %%
program = """\
    @test(test)
    class A(abc):
        @diffable
        def __init__():
            pass\
"""

# %%
parser.parse_root_children(program)
# Out:
# [('@test(test)<nl>    class A(abc):<nl>        @diffable<nl>        def __init__():<nl>            pass',
#   '(decorated_definition (decorator (dotted_name (test)) arguments: (argument_list (test))) definition: (class_definition name: (A) superclasses: (argument_list (abc)) body: (block (decorated_definition (decorator (dotted_name (diffable))) definition: (function_definition name: (__init__) parameters: (parameters) body: (block (pass_statement)))))))'),
#  ('@test(test)',
#   '(decorator (dotted_name (test)) arguments: (argument_list (test)))'),
#  ('class A(abc):',
#   '(class_definition name: (A) superclasses: (argument_list (abc)))'),
#  ('class A(abc):<nl>        @diffable<nl>        def __init__():<nl>            pass',
#   '(class_definition name: (A) superclasses: (argument_list (abc)) body: (block (decorated_definition (decorator (dotted_name (diffable))) definition: (function_definition name: (__init__) parameters: (parameters) body: (block (pass_statement))))))'),
#  ('@diffable<nl>        def __init__():<nl>            pass',
#   '(decorated_definition (decorator (dotted_name (diffable))) definition: (function_definition name: (__init__) parameters: (parameters) body: (block (pass_statement))))'),
#  ('@diffable', '(decorator (dotted_name (diffable)))'),
#  ('def __init__():',
#   '(function_definition name: (__init__) parameters: (parameters))'),
#  ('def __init__():<nl>            pass',
#   '(function_definition name: (__init__) parameters: (parameters) body: (block (pass_statement)))')]

# %%
tree = parser.parser.parse(bytes(program, "utf8"))
root_node = tree.root_node

# %%
root_node.children

# %%
root_node.children[0].children

# %%
root_node.children[0].children[2].sexp()

# %% [markdown]
# # Utils to train a BPE tokenization model

# %%
import sentencepiece as spm
import os

# %%
def train_bpe_model(
    input_path: str, 
    model_name: str, 
    vocab_size: int, 
    input_sentence_size: int = 1000
):
    symbols_str = "<nl>,\",(,),.,{,}"
    train_args = f"""--input={input_path} \
            --user_defined_symbols={symbols_str} \
            --model_prefix={model_name} \
            --pad_id=3 \
            --pad_piece=<pad> \
            --vocab_size={vocab_size} \
            --hard_vocab_limit={False} \
            --input_sentence_size={input_sentence_size} \
            --model_type=bpe"""
    spm.SentencePieceTrainer.Train(train_args)

# %%
train_bpe_model(
    input_path="/workspace/tmp/data_test/dataset_tmp.train", 
    model_name="ast_model", 
    vocab_size=16_000
)

# %% [markdown]
# # Utils to decode word pieces into words

# %%
def decode_pieces(model_path, input_path, output_path):
    proc = spm.SentencePieceProcessor()
    if not proc.load(model_path):
        return
    
    dirname = os.path.dirname(output_path)
    os.makedirs(dirname, exist_ok=True)
    
    input_file = open(input_path, mode="r")
    output_file = open(output_path, mode="w")
    
    with input_file, output_file:
        encoded_lines = input_file.readlines()
        decoded_lines = [proc.decode_pieces(line.split(" ")) for line in encoded_lines]
        output_file.writelines(decoded_lines)

# %%
decode_pieces(
    "/workspace/src_model.model", 
    "/workspace/tmp/ast_test/code2ast_tokenized/train2.src", 
    "/workspace/tmp/ast_test/code2ast_detokenized/train.src"
)

# %%
decode_pieces(
    "/workspace/ast_model.model", 
    "/workspace/tmp/ast_test/code2ast_bpe/train.ast", 
    "/workspace/tmp/ast_test/code2ast_bpe_decoded/train.ast"
)

# %% [markdown]
# # Make up a list of repositories to clone

# %%
import pandas as pd

# %%
df = pd.read_json("/workspace/data/repositories/top1000_page1.jsonl", lines=False)

# %%
df.sort_values("size", ascending=False)[:50]
# Out:
#                                     full_name language  commits  \
# 55                                  odoo/odoo   Python   131512
# 705            googleapis/google-cloud-python   Python     8689
# 887                          RasaHQ/rasa_core   Python     4698
# 335                            frappe/erpnext   Python    28974
# 650                           librosa/librosa   Python     2936
# 359                              ytisf/theZoo   Python      200
# 244                         Yorko/mlcourse.ai   Python     4980
# 737                 iGhibli/iOS-DeviceSupport   Python       66
# 332                       samuelclay/NewsBlur   Python    12738
# 3                           tensorflow/models   Python     3936
# 214                               RasaHQ/rasa   Python    13319
# 194                               RasaHQ/rasa   Python    13319
# 846          aosp-mirror/platform_development   Python    27100
# 95                         iperov/DeepFaceLab   Python      626
# 111                                rsms/inter   Python      899
# 124         CorentinJ/Real-Time-Voice-Cloning   Python      237
# 534                              cloudera/hue   Python    16845
# 146                                 nltk/nltk   Python    13810
# 354                    chrissimpkins/codeface   Python      605
# 207              Unity-Technologies/ml-agents   Python     1542
# 187              Unity-Technologies/ml-agents   Python     1542
# 761            AKSHAYUBHAT/DeepVideoAnalytics   Python     3223
# 627                       PaddlePaddle/models   Python     3958
# 882                       datawire/ambassador   Python     9607
# 917                       datawire/ambassador   Python     9607
# 228                        kovidgoyal/calibre   Python    39346
# 109                   miloyip/game-programmer   Python       83
# 377  shengqiangzhang/examples-of-web-crawlers   Python      171
# 96                                zulip/zulip   Python    33630
# 134                         tzutalin/labelImg   Python      344
# 914                            pypa/warehouse   Python     4897
# 39                                pypa/pipenv   Python     6526
# 197                               ansible/awx   Python    23318
# 218                               ansible/awx   Python    23318
# 292                microsoft/botframework-sdk   Python     2291
# 867                     sightmachine/SimpleCV   Python     2625
# 902                     sightmachine/SimpleCV   Python     2625
# 21                         deepfakes/faceswap   Python      965
# 366           google-research/google-research   Python      465
# 12                            ansible/ansible   Python    48055
# 8                               django/django   Python    27513
# 596                                 yhat/ggpy   Python      256
# 564                   misterch0c/shadowbroker   Python       24
# 395        trustedsec/social-engineer-toolkit   Python    15692
# 727              andabi/deep-voice-conversion   Python      106
# 195                            NVIDIA/vid2vid   Python       65
# 215                            NVIDIA/vid2vid   Python       65
# 30                          pandas-dev/pandas   Python    20564
# 61                            explosion/spaCy   Python    11037
# 731                        golemfactory/golem   Python     9850
#
#      stargazers_count  watchers_count  forks_count     size  archived   fork
# 55              15608           15608        11183  2741739     False  False
# 705              2874            2874         1209  1778249     False  False
# 887              2291            2291         1048  1059972      True  False
# 335              5306            5306         2322   804911     False  False
# 650              3106            3106          543   760281     False  False
# 359              5066            5066         1474   688056     False  False
# 244              6348            6348         4164   644447     False  False
# 737              2798            2798          413   554436     False  False
# 332              5333            5333          918   525458     False  False
# 3               58983           58983        37248   523487     False  False
# 214              6959            6959         2154   482687     False  False
# 194              6959            6959         2154   482687     False  False
# 846              2399            2399         2525   460787     False  False
# 95              10641           10641         2450   411634     False  False
# 111              9783            9783          200   373630     False  False
# 124              9111            9111         1423   369614     False  False
# 534              3807            3807         1476   364657     False  False
# 146              8312            8312         2249   346883     False  False
# 354              5098            5098          381   317134     False  False
# 207              7109            7109         1840   314629     False  False
# 187              7109            7109         1840   314629     False  False
# 761              2741            2741          655   297194     False  False
# 627              3180            3180         1560   282149     False  False
# 882              2304            2304          345   260390     False  False
# 917              2304            2304          345   260390     False  False
# 228              6586            6586         1131   256283     False  False
# 109              9801            9801         1204   253417     False  False
# 377              4966            4966         1565   251503     False  False
# 96              10601           10601         3294   245739     False  False
# 134              8800            8800         3009   238188     False  False
# 914              2314            2314          641   237806     False  False
# 39              18738           18738         1406   236710     False  False
# 197              6796            6796         1631   221462     False  False
# 218              6796            6796         1631   221462     False  False
# 292              5770            5770         2196   217553     False  False
# 867              2355            2355          714   204103     False  False
# 902              2355            2355          714   204103     False  False
# 21              27149           27149         8760   197611     False  False
# 366              5029            5029          783   196957     False  False
# 12              40098           40098        17300   193870     False  False
# 8               45043           45043        19418   190821     False  False
# 596              3505            3505          562   186091     False  False
# 564              3639            3639          270   182405     False  False
# 395              4841            4841         1562   179360     False  False
# 727              2822            2822          632   172486     False  False
# 195              6942            6942          940   172394     False  False
# 215              6942            6942          940   172394     False  False
# 30              22121           22121         8815   171885     False  False
# 61              15006           15006         2605   171040     False  False
# 731              2818            2818          307   163771     False  False

# %%
selected_list_idx = [705, 887, 244, 3, 214, 146, 218, 12, 21, 215, 30, 61, 366]

# %%
selected_urls = [f"https://github.com/{df.iloc[idx].full_name}.git" for idx in selected_list_idx]
selected_urls_path = "/workspace/tmp/ast_test/repo_list.txt"
with open(selected_urls_path, mode="w") as file:
    file.writelines("\n".join(selected_urls))
